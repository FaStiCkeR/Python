# %% [markdown]
# # Лабораторная работа №7

# %% [markdown]
# ## **Цель работы**
#
# Освоить разработку веб-приложений с использованием Flask, научиться работать с маршрутизацией, шаблонами, формами, базой данных и структурированием проекта.
#
#
#
# ## **Задание**
#
# Создать веб-приложение средней сложности с использованием Flask.
#
# 👉 **Тематика приложения выбирается студентом самостоятельно**
# (например: список задач, заметки, фильмы, книги, заказы, студенты и т.д.).
#
#
#
# ## **Функциональные требования**
#
# ### **1. Основа приложения**
#
# Создать Flask-приложение с корректной структурой проекта:
#
# ```
# project/
# ├── app.py
# ├── templates/
# ├── static/
# ├── database.db
# └── models.py (по желанию)
# ```
#
#
# ### **2. Работа с маршрутами (routes)**
#
# Реализовать минимум следующие страницы:
#
# 1. **Главная страница /**
#
#    * краткое описание приложения
#
# 2. **Страница списка объектов (например: /items)**
#
#    * отображение всех записей
#
# 3. **Страница одного объекта (/items/<id>)**
#
#    * подробная информация
#
# 4. **Страница добавления (/add)**
#
#    * форма для создания новой записи
#
#
# ### **3. Работа с формами**
#
# Реализовать HTML-форму для добавления данных.
#
# 👉 Поля формы определяются выбранной тематикой
# (например: название, описание, категория, цена и т.д.)
#
# Обязательно:
#
# * проверка на пустые значения;
# * проверка типов данных (числа, строки);
# * обработка POST-запроса.
#
#
# ### **4. Работа с базой данных (SQLite)**
#
# Создать таблицу (название и поля определяются темой).
#
# 👉 Обязательные требования:
#
# * наличие `id` (PRIMARY KEY);
# * минимум 4–5 полей;
# * одно поле с датой (`created_at` или аналог).
#
# Реализовать:
#
# * добавление записи;
# * получение всех записей;
# * получение одной записи по ID.
#
# ### **5. Аналитика данных**
#
# Создать страницу **/stats**, которая отображает:
#
# * общее количество записей;
# * один или несколько агрегированных показателей
#   (например: сумма, среднее, количество по категориям и т.д.)
#
# 👉 Логика анализа зависит от выбранной темы.
#
#
# ### **6. Шаблоны (Jinja2)**
#
# Использовать:
#
# * базовый шаблон (`base.html`);
# * наследование шаблонов;
# * циклы (`for`) и условия (`if`).
#
# ### **7. Дополнительный функционал (обязательно выбрать минимум один)**
#
# * фильтрация данных;
# * сортировка;
# * удаление записи;
# * редактирование записи.
#
# ## **Требования**
#
# * корректное использование Flask (routes, templates);
# * использование SQLite;
# * логичное соответствие функционала выбранной теме;
# * обработка ошибок;
# * читаемый и структурированный код.
#
# ## **Результат**
#
# Веб-приложение, которое:
#
# * реализует выбранную студентом тематику;
# * позволяет добавлять, просматривать и анализировать данные;
# * содержит элементы аналитики и обработки данных.
#
# ## **Защита работы**
#
# Студент должен объяснить:
#
# * выбранную тему и структуру данных;
# * реализацию маршрутов;
# * работу с базой данных;
# * обработку форм и валидацию;
# * реализованный дополнительный функционал.

# %%
# Напиши решение тут
